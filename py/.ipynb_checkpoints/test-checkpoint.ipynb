# %%
x = [1,2,3,4]

# %%
import math

# %%
def getMax(List,f,e):
    if f == e:
        return List[f]
    
    mid = (f+e)/2
    left = getMax(List,f,mid)
    right = getMax(List,mid+1,e)
    return math.max(left,right)

# %%
getMax(x,0,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-2a69ebaae064> in <module>
# ----> 1 getMax(x,0,3)
#
# <ipython-input-7-2a412ca23314> in getMax(List, f, e)
#       4
#       5     mid = (f+e)/2
# ----> 6     left = getMax(List,f,mid)
#       7     right = getMax(List,mid+1,e)
#       8     return Math.max(left,right)
#
# <ipython-input-7-2a412ca23314> in getMax(List, f, e)
#       4
#       5     mid = (f+e)/2
# ----> 6     left = getMax(List,f,mid)
#       7     right = getMax(List,mid+1,e)
#       8     return Math.max(left,right)
#
# <ipython-input-7-2a412ca23314> in getMax(List, f, e)
#       4
#       5     mid = (f+e)/2
# ----> 6     left = getMax(List,f,mid)
#       7     right = getMax(List,mid+1,e)
#       8     return Math.max(left,right)
#
# <ipython-input-7-2a412ca23314> in getMax(List, f, e)
#       4
#       5     mid = (f+e)/2
# ...
